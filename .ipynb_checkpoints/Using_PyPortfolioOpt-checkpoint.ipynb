# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import pypfopt
from pypfopt import risk_models, expected_returns, plotting
import yfinance as yf


from datetime import date

# %%
risk_free = 0.08                                  #УКАЖИТЕ ГОДОВОЙ ДОХОД БЕЗРИСКОВЫХ ИНВЕСТИЦИЙ
total_money = 2000                               #УКАЖИТЕ НА КАКУЮ СУММУ СОБРАТЬ ПОРТФЕЛЬ

listtick = []
#listtick = "aflt.me gazp.me gche.me gltr.me irao.me mgnt.me moex.me mtlr.me 
# mtss.me nkncp.me nvtk.me ozon.me pikk.me poly.me qiwi.me rosn.me rtkm.me 
# sgzh.me sibn.me sngsp.me tatn.me trmk.me vkco.me".upper().split(" ")   #НАПИСАТЬ ТИКЕРЫ ВРУЧНУЮ

k = 200                                          #ИНАЧЕ ВЗЯТЬ k КРУПНЕЙШИХ КОМПАНИЙ NASDAC ИЗ ФАЙЛА
if len(listtick) == 0:
    listtick = pd.read_csv('nasdaq_screener_1684050394168.csv')
    listtick = listtick.sort_values("Market Cap", ascending=False).iloc[:k].Symbol.to_list()

print(listtick)
# Out:
# ['AAPL', 'MSFT', 'GOOG', 'GOOGL', 'AMZN', 'NVDA', 'META', 'TSLA', 'JNJ', 'V', 'UNH', 'TSM', 'XOM', 'LLY', 'WMT', 'JPM', 'NVO', 'PG', 'MA', 'MRK', 'CVX', 'HD', 'KO', 'PEP', 'ORCL', 'AVGO', 'ABBV', 'ASML', 'AZN', 'COST', 'BABA', 'NVS', 'MCD', 'BAC', 'PFE', 'SHEL', 'TMO', 'CRM', 'TM', 'ABT', 'CSCO', 'NKE', 'LIN', 'FMX', 'ACN', 'TMUS', 'CMCSA', 'DIS', 'DHR', 'VZ', 'NEE', 'AMD', 'ADBE', 'SAP', 'NFLX', 'HSBC', 'PM', 'BHP', 'TTE', 'TXN', 'UPS', 'WFC', 'BMY', 'RTX', 'MS', 'UL', 'SNY', 'RY', 'HON', 'HDB', 'AMGN', 'SBUX', 'T', 'UNP', 'LOW', 'BUD', 'INTC', 'COP', 'BA', 'INTU', 'MDT', 'SPGI', 'SONY', 'PLD', 'QCOM', 'LMT', 'TD', 'IBM', 'DE', 'AXP', 'ELV', 'SYK', 'CAT', 'GE', 'ISRG', 'GS', 'MDLZ', 'BP', 'DEO', 'RIO', 'AMAT', 'BKNG', 'GILD', 'BLK', 'AMT', 'NOW', 'ADI', 'TJX', 'MMC', 'VRTX', 'SCHW', 'C', 'ADP', 'CVS', 'EQNR', 'ZTS', 'CB', 'REGN', 'MO', 'IBN', 'SO', 'PDD', 'CNI', 'SHOP', 'PGR', 'ENB', 'MUFG', 'UBER', 'PBR', 'BSX', 'HCA', 'CP', 'CI', 'BTI', 'DUK', 'FISV', 'GSK', 'TGT', 'BDX', 'EL', 'LRCX', 'AMX', 'ITW', 'CHTR', 'PYPL', 'EQIX', 'AON', 'WM', 'ABB', 'CL', 'ETN', 'NOC', 'MU', 'CME', 'HUM', 'EOG', 'CSX', 'MELI', 'SLB', 'ABNB', 'INFY', 'BMO', 'MNST', 'BX', 'APD', 'VALE', 'CNQ', 'ICE', 'ATVI', 'PANW', 'ORLY', 'RELX', 'SHW', 'BNS', 'UBS', 'TRI', 'GD', 'MCO', 'CMG', 'SMFG', 'EPD', 'SNPS', 'HSY', 'FDX', 'NTES', 'JD', 'MMM', 'SAN', 'CDNS', 'NGG', 'SNOW', 'EW', 'RACE', 'MAR', 'SCCO', 'KLAC', 'FTNT', 'MCK', 'GIS', 'ITUB']

# %% [markdown]
# Скачиваем котировки:

# %%
today = str(date.today())
print(today) 

df = yf.download(listtick, start = "2015-01-01", end=today).Close.dropna(axis=1, how='all')
df.tail()
# Out:
# 2023-05-14
# [*********************100%***********************]  200 of 200 completed
#                   AAPL        ABB        ABBV        ABNB         ABT
# Date
# 2023-05-08  173.500000  36.139999  147.449997  125.650002  110.900002  \
# 2023-05-09  171.770004  36.570000  146.830002  127.070000  110.250000
# 2023-05-10  173.559998  36.459999  146.419998  113.190002  110.690002
# 2023-05-11  173.750000  36.730000  146.589996  111.199997  110.050003
# 2023-05-12  172.570007  36.930000  147.149994  105.275002  110.489998
#
#                    ACN        ADBE         ADI         ADP        AMAT  ...
# Date                                                                    ...
# 2023-05-08  264.820007  344.059998  184.520004  214.270004  115.750000  ...  \
# 2023-05-09  263.480011  342.649994  179.619995  213.660004  113.839996  ...
# 2023-05-10  268.890015  344.019989  181.429993  215.009995  115.410004  ...
# 2023-05-11  272.269989  341.579987  180.589996  209.809998  115.459999  ...
# 2023-05-12  277.190002  335.450012  180.570007  212.740005  116.089996  ...
#
#                    UPS           V   VALE        VRTX         VZ        WFC
# Date
# 2023-05-08  174.389999  232.229996  13.90  344.089996  37.830002  38.380001  \
# 2023-05-09  173.009995  233.259995  14.10  344.829987  37.570000  38.540001
# 2023-05-10  171.570007  231.270004  14.00  350.040009  37.630001  38.279999
# 2023-05-11  170.229996  231.009995  13.71  350.399994  37.599998  38.330002
# 2023-05-12  168.500000  231.380005  13.78  347.410004  37.590000  37.490002
#
#                     WM         WMT         XOM         ZTS
# Date
# 2023-05-08  169.029999  152.720001  109.110001  184.869995
# 2023-05-09  169.460007  152.979996  109.139999  184.369995
# 2023-05-10  170.550003  152.550003  107.739998  185.139999
# 2023-05-11  170.190002  153.119995  105.790001  185.119995
# 2023-05-12  169.240005  153.070007  105.779999  183.619995
#
# [5 rows x 200 columns]

# %% [markdown]
# По приколу выведем котировки 10-ти каких то акций

# %%
if len(df) >= 10 :
    df.iloc[-1004:, 0:10].plot(figsize=(15,10))
else:
    df.plot(figsize=(15,10))

# %% [markdown]
# Теперь сделаем матрицу ковариации наших активов.

# %%
rm = risk_models.risk_matrix(df, method="exp_cov", span=252)
rm = pypfopt.risk_models.fix_nonpositive_semidefinite(rm)

sns.heatmap(rm, cmap='viridis')
# Out:
# <Axes: >

# %% [markdown]
# Теперь посчитаем оценку для доходностей каждого актива

# %%
er = expected_returns.return_model(df, method="capm_return")
er.plot.barh(figsize=(20, 12));

# %% [markdown]
# Теперь сделаем оптимизацию портфеля

# %%
ef = pypfopt.EfficientFrontier(er, rm)
ef.add_objective(pypfopt.objective_functions.L2_reg, gamma=0)  #УВЕЛИЧИТЬ ПАРАМЕТР ГАММА ЕСЛИ ХОЧЕТСЯ БОЛЬШЕ АКЦИЙ В ПОРТФЕЛЕ
ef.max_sharpe(risk_free)

print("Колличество активов в портфеле: ", np.count_nonzero(np.array(list(ef.clean_weights().values()))))
print("Параметры полученого портфеля: ")

ef.portfolio_performance(verbose=True, risk_free_rate=risk_free)


print("Полученные веса портфеля: ")
weig = pd.Series(ef.clean_weights())
weig = weig[weig != 0]
print(weig.sort_values(ascending=False))

pd.Series(ef.clean_weights(), index = ef.tickers).plot.pie(figsize=(6, 6));
# Out:
# c:\users\mi\appdata\local\programs\python\python39\lib\site-packages\pypfopt\efficient_frontier\efficient_frontier.py:259: UserWarning: max_sharpe transforms the optimization problem so additional objectives may not work as expected.
#   warnings.warn(
# Колличество активов в портфеле:  18
# Параметры полученого портфеля:
# Expected annual return: 18.0%
# Annual volatility: 19.4%
# Sharpe Ratio: 0.51
# Полученные веса портфеля:
# UBER    0.17831
# PBR     0.13769
# MS      0.09052
# AMX     0.07286
# AMGN    0.07201
# VALE    0.06972
# MU      0.06884
# BSX     0.06477
# UNH     0.05620
# VRTX    0.04168
# RTX     0.04151
# ABBV    0.03531
# BA      0.02224
# CSX     0.01827
# ATVI    0.01376
# C       0.01097
# COP     0.00471
# AVGO    0.00064
# dtype: float64

# %%
da = pypfopt.DiscreteAllocation(ef.clean_weights(), df.iloc[-1], total_portfolio_value=total_money) #ВЫЧЕСЛИТЬ В ЦЕЛЫХ ЧИСЛАХ
alloc, leftover = da.lp_portfolio(verbose=True)  
print(f"Дискретный портфель на ${(total_money-leftover):.2f} с остатком денег: ${leftover:.2f}")
print(pd.Series(alloc))
pd.Series(alloc).plot.bar();
# Out:
# c:\users\mi\appdata\local\programs\python\python39\lib\site-packages\cvxpy\problems\problem.py:1385: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# Funds remaining: 133.42
# AAPL: allocated 0.000, desired 0.000
# ABB: allocated 0.000, desired 0.000
# ABBV: allocated 0.079, desired 0.035
# ABNB: allocated 0.000, desired 0.000
# ABT: allocated 0.000, desired 0.000
# ACN: allocated 0.000, desired 0.000
# ADBE: allocated 0.000, desired 0.000
# ADI: allocated 0.000, desired 0.000
# ADP: allocated 0.000, desired 0.000
# AMAT: allocated 0.000, desired 0.000
# AMD: allocated 0.000, desired 0.000
# AMGN: allocated 0.125, desired 0.072
# AMT: allocated 0.000, desired 0.000
# AMX: allocated 0.083, desired 0.073
# AMZN: allocated 0.000, desired 0.000
# AON: allocated 0.000, desired 0.000
# APD: allocated 0.000, desired 0.000
# ASML: allocated 0.000, desired 0.000
# ATVI: allocated 0.000, desired 0.014
# AVGO: allocated 0.000, desired 0.001
# AXP: allocated 0.000, desired 0.000
# AZN: allocated 0.000, desired 0.000
# BA: allocated 0.000, desired 0.022
# BABA: allocated 0.000, desired 0.000
# BAC: allocated 0.000, desired 0.000
# BDX: allocated 0.000, desired 0.000
# BHP: allocated 0.000, desired 0.000
# BKNG: allocated 0.000, desired 0.000
# BLK: allocated 0.000, desired 0.000
# BMO: allocated 0.000, desired 0.000
# BMY: allocated 0.000, desired 0.000
# BNS: allocated 0.000, desired 0.000
# BP: allocated 0.000, desired 0.000
# BSX: allocated 0.086, desired 0.065
# BTI: allocated 0.000, desired 0.000
# BUD: allocated 0.000, desired 0.000
# BX: allocated 0.000, desired 0.000
# C: allocated 0.000, desired 0.011
# CAT: allocated 0.000, desired 0.000
# CB: allocated 0.000, desired 0.000
# CDNS: allocated 0.000, desired 0.000
# CHTR: allocated 0.000, desired 0.000
# CI: allocated 0.000, desired 0.000
# CL: allocated 0.000, desired 0.000
# CMCSA: allocated 0.000, desired 0.000
# CME: allocated 0.000, desired 0.000
# CMG: allocated 0.000, desired 0.000
# CNI: allocated 0.000, desired 0.000
# CNQ: allocated 0.000, desired 0.000
# COP: allocated 0.000, desired 0.005
# COST: allocated 0.000, desired 0.000
# CP: allocated 0.000, desired 0.000
# CRM: allocated 0.000, desired 0.000
# CSCO: allocated 0.000, desired 0.000
# CSX: allocated 0.017, desired 0.018
# CVS: allocated 0.000, desired 0.000
# CVX: allocated 0.000, desired 0.000
# DE: allocated 0.000, desired 0.000
# DEO: allocated 0.000, desired 0.000
# DHR: allocated 0.000, desired 0.000
# DIS: allocated 0.000, desired 0.000
# DUK: allocated 0.000, desired 0.000
# EL: allocated 0.000, desired 0.000
# ELV: allocated 0.000, desired 0.000
# ENB: allocated 0.000, desired 0.000
# EOG: allocated 0.000, desired 0.000
# EPD: allocated 0.000, desired 0.000
# EQIX: allocated 0.000, desired 0.000
# EQNR: allocated 0.000, desired 0.000
# ETN: allocated 0.000, desired 0.000
# EW: allocated 0.000, desired 0.000
# FDX: allocated 0.000, desired 0.000
# FISV: allocated 0.000, desired 0.000
# FMX: allocated 0.000, desired 0.000
# FTNT: allocated 0.000, desired 0.000
# GD: allocated 0.000, desired 0.000
# GE: allocated 0.000, desired 0.000
# GILD: allocated 0.000, desired 0.000
# GIS: allocated 0.000, desired 0.000
# GOOG: allocated 0.000, desired 0.000
# GOOGL: allocated 0.000, desired 0.000
# GS: allocated 0.000, desired 0.000
# GSK: allocated 0.000, desired 0.000
# HCA: allocated 0.000, desired 0.000
# HD: allocated 0.000, desired 0.000
# HDB: allocated 0.000, desired 0.000
# HON: allocated 0.000, desired 0.000
# HSBC: allocated 0.000, desired 0.000
# HSY: allocated 0.000, desired 0.000
# HUM: allocated 0.000, desired 0.000
# IBM: allocated 0.000, desired 0.000
# IBN: allocated 0.000, desired 0.000
# ICE: allocated 0.000, desired 0.000
# INFY: allocated 0.000, desired 0.000
# INTC: allocated 0.000, desired 0.000
# INTU: allocated 0.000, desired 0.000
# ISRG: allocated 0.000, desired 0.000
# ITUB: allocated 0.000, desired 0.000
# ITW: allocated 0.000, desired 0.000
# JD: allocated 0.000, desired 0.000
# JNJ: allocated 0.000, desired 0.000
# JPM: allocated 0.000, desired 0.000
# KLAC: allocated 0.000, desired 0.000
# KO: allocated 0.000, desired 0.000
# LIN: allocated 0.000, desired 0.000
# LLY: allocated 0.000, desired 0.000
# LMT: allocated 0.000, desired 0.000
# LOW: allocated 0.000, desired 0.000
# LRCX: allocated 0.000, desired 0.000
# MA: allocated 0.000, desired 0.000
# MAR: allocated 0.000, desired 0.000
# MCD: allocated 0.000, desired 0.000
# MCK: allocated 0.000, desired 0.000
# MCO: allocated 0.000, desired 0.000
# MDLZ: allocated 0.000, desired 0.000
# MDT: allocated 0.000, desired 0.000
# MELI: allocated 0.000, desired 0.000
# META: allocated 0.000, desired 0.000
# MMC: allocated 0.000, desired 0.000
# MMM: allocated 0.000, desired 0.000
# MNST: allocated 0.000, desired 0.000
# MO: allocated 0.000, desired 0.000
# MRK: allocated 0.000, desired 0.000
# MS: allocated 0.088, desired 0.091
# MSFT: allocated 0.000, desired 0.000
# MU: allocated 0.065, desired 0.069
# MUFG: allocated 0.000, desired 0.000
# NEE: allocated 0.000, desired 0.000
# NFLX: allocated 0.000, desired 0.000
# NGG: allocated 0.000, desired 0.000
# NKE: allocated 0.000, desired 0.000
# NOC: allocated 0.000, desired 0.000
# NOW: allocated 0.000, desired 0.000
# NTES: allocated 0.000, desired 0.000
# NVDA: allocated 0.000, desired 0.000
# NVO: allocated 0.000, desired 0.000
# NVS: allocated 0.000, desired 0.000
# ORCL: allocated 0.000, desired 0.000
# ORLY: allocated 0.000, desired 0.000
# PANW: allocated 0.000, desired 0.000
# PBR: allocated 0.146, desired 0.138
# PDD: allocated 0.000, desired 0.000
# PEP: allocated 0.000, desired 0.000
# PFE: allocated 0.000, desired 0.000
# PG: allocated 0.000, desired 0.000
# PGR: allocated 0.000, desired 0.000
# PLD: allocated 0.000, desired 0.000
# PM: allocated 0.000, desired 0.000
# PYPL: allocated 0.000, desired 0.000
# QCOM: allocated 0.000, desired 0.000
# RACE: allocated 0.000, desired 0.000
# REGN: allocated 0.000, desired 0.000
# RELX: allocated 0.000, desired 0.000
# RIO: allocated 0.000, desired 0.000
# RTX: allocated 0.051, desired 0.042
# RY: allocated 0.000, desired 0.000
# SAN: allocated 0.000, desired 0.000
# SAP: allocated 0.000, desired 0.000
# SBUX: allocated 0.000, desired 0.000
# SCCO: allocated 0.000, desired 0.000
# SCHW: allocated 0.000, desired 0.000
# SHEL: allocated 0.000, desired 0.000
# SHOP: allocated 0.000, desired 0.000
# SHW: allocated 0.000, desired 0.000
# SLB: allocated 0.000, desired 0.000
# SMFG: allocated 0.000, desired 0.000
# SNOW: allocated 0.000, desired 0.000
# SNPS: allocated 0.000, desired 0.000
# SNY: allocated 0.000, desired 0.000
# SO: allocated 0.000, desired 0.000
# SONY: allocated 0.000, desired 0.000
# SPGI: allocated 0.000, desired 0.000
# SYK: allocated 0.000, desired 0.000
# T: allocated 0.000, desired 0.000
# TD: allocated 0.000, desired 0.000
# TGT: allocated 0.000, desired 0.000
# TJX: allocated 0.000, desired 0.000
# TM: allocated 0.000, desired 0.000
# TMO: allocated 0.000, desired 0.000
# TMUS: allocated 0.000, desired 0.000
# TRI: allocated 0.000, desired 0.000
# TSLA: allocated 0.000, desired 0.000
# TSM: allocated 0.000, desired 0.000
# TTE: allocated 0.000, desired 0.000
# TXN: allocated 0.000, desired 0.000
# UBER: allocated 0.185, desired 0.178
# UBS: allocated 0.000, desired 0.000
# UL: allocated 0.000, desired 0.000
# UNH: allocated 0.000, desired 0.056
# UNP: allocated 0.000, desired 0.000
# UPS: allocated 0.000, desired 0.000
# V: allocated 0.000, desired 0.000
# VALE: allocated 0.074, desired 0.070
# VRTX: allocated 0.000, desired 0.042
# VZ: allocated 0.000, desired 0.000
# WFC: allocated 0.000, desired 0.000
# WM: allocated 0.000, desired 0.000
# WMT: allocated 0.000, desired 0.000
# XOM: allocated 0.000, desired 0.000
# ZTS: allocated 0.000, desired 0.000
# Allocation has RMSE: 0.007
# Дискретный портфель на $1866.58 с остатком денег: $133.42
# ABBV     1
# AMGN     1
# AMX      7
# BSX      3
# CSX      1
# MS       2
# MU       2
# PBR     23
# RTX      1
# UBER     9
# VALE    10
# dtype: int32

# %% [markdown]
# Далее пример кода показывающий как любой случайный портфель ~~отсасывает~~ проигрывает у портфеля найденного методом оптимизации. Создадим случайные 10000 портфелей и сравним с оптимальным

# %%
n_samples = 10000
w = np.random.dirichlet(np.ones(len(er)), n_samples)
rets = w.dot(er)
stds = np.sqrt((w.T * (rm @ w.T)).sum(axis=0))
sharpes = rets / stds

print("Sample portfolio returns:", rets)
print("Sample portfolio volatilities:", stds)
# Out:
# Sample portfolio returns: [0.13654948 0.13424461 0.13816896 ... 0.13590136 0.13450107 0.14041624]
# Sample portfolio volatilities: 0       0.174576
# 1       0.170932
# 2       0.181184
# 3       0.179844
# 4       0.173766
#           ...
# 9995    0.176934
# 9996    0.176954
# 9997    0.176705
# 9998    0.169117
# 9999    0.180919
# Length: 10000, dtype: float64

# %%
# Plot efficient frontier with Monte Carlo sim
ef = pypfopt.EfficientFrontier(er, rm)

fig, ax = plt.subplots()
plotting.plot_efficient_frontier(ef, ax=ax, show_assets=False)

# Find and plot the tangency portfolio
ef2 = pypfopt.EfficientFrontier(er, rm)
ef2.max_sharpe(risk_free_rate=risk_free)
ret_tangent, std_tangent, _ = ef2.portfolio_performance()

# Plot random portfolios
ax.scatter(stds, rets, marker=".", c=sharpes, cmap="viridis_r")

ax.scatter(std_tangent, ret_tangent, marker="*", label="Max Sharp ratio", c="red") 
# Format
ax.set_title("Efficient Frontier with random portfolios")
ax.legend()
plt.tight_layout()
plt.show()
# Out:
# c:\users\mi\appdata\local\programs\python\python39\lib\site-packages\pypfopt\efficient_frontier\efficient_frontier.py:441: UserWarning: The risk_free_rate provided to portfolio_performance is different to the one used by max_sharpe. Using the previous value.
#   warnings.warn(

# %% [markdown]
# На данном графике по вертикале доходность, а по горизонтали величина отклонения в год. Грубо говоря наше оптимальное решение в год будет приносить 18% $\pm$ 19%  . Любой портфель не находящийся на фронте эффективности хуже.
